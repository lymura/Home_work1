# %% [markdown]
# <a href="https://colab.research.google.com/github/lymura/Home_work1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3_5_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# сфера
fig = plt.figure(figsize=(8,6),facecolor='white')

ax = fig.add_subplot(2, 2, 1, projection='3d')
u = np.linspace(0, 2 * np.pi, 51)
v = np.linspace(-np.pi/2, np.pi/2, 51)
x = np.outer(np.cos(u), np.cos(v))
y = np.outer(np.sin(u), np.cos(v))
z = np.outer(np.ones(np.size(u)), np.sin(v))
ax.plot_surface(x, y, z, rstride=1, cstride=1, linewidth=0,color=(0.5, 0.5, 1))
#парабола
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z1 =  np.sqrt(5.*(X**2 + Y**2)/1. + 2)
xcolors = X - min(X.flat)
xcolors = xcolors/max(xcolors.flat)
ax.plot_surface(X, Y, Z1, facecolors=cm.hot(xcolors))
#параболический цилиндр
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-50, 50, 1)
Y = np.arange(-50, 50, 1)
X, Y = np.meshgrid(X, Y)
Z = (X**2/3**2) - (Y**2/8**2)
ax.plot_surface(X, Y, Z)
plt.show()

# %%
# Out:
#   File "<ipython-input-25-d3e744794c1f>", line 20
#     surf = ax.plot_surface(X, Y, Z, facecolors=cm.hot(xcolors))
#        ^
# SyntaxError: invalid syntax
