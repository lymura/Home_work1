# %% [markdown]
# <a href="https://colab.research.google.com/github/lymura/Home_work1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B533_3_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

def pol2cart(rho, phi):
    x = rho * math.cos(math.radians(phi))
    y = rho * math.sin(math.radians(phi))
    return(x, y)

rho=float(input("Enter the value of rho:"))
phi=float(input("Enter the value of phi in degrees:"))

print("For the polar coordinates x = ", rho, "and y = ", phi, "the cartesian coordinates are = ", pol2cart(rho, phi))
# Out:
# Enter the value of rho:1
# Enter the value of phi in degrees:30
# For the polar coordinates x =  1.0 and y =  30.0 the cartesian coordinates are =  (0.8660254037844387, 0.49999999999999994)

# %%
#график окружности в полярных координатах
import matplotlib.pyplot as plt
import numpy as np
 #уравнение окружности в полярных координатах вар 1

x = np.linspace(-5, 5, 1000)
y1 = np.sqrt((r**2 - x**2)/3)
y2 = -np.sqrt((r**2 - x**2)/3)

plt.polar(x, y1)
plt.polar(x, y2)  
#уравнение окружности в полярных координатах вар2  
import numpy as np
import matplotlib.pyplot as plt

# theta goes from 0 to 2pi
theta = np.linspace(0, 2*np.pi, 100)

# радиус окружности
r = np.sqrt(0.6)

# вычислить x1 и x2
x1 = r*np.cos(theta)
x2 = r*np.sin(theta)

# нарисовать график
fig, ax = plt.subplots(1)
ax.plot(x1, x2)
ax.set_aspect(1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sqrt

# %%
#график отрезка прямой в полярных координатах 
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-1, 3, 201)
y = 3 * x + 5
plt.plot(x, y)
plt.show()
x1 = np.linspace(-1, 3, 201)
plt.polar(x1, y)
