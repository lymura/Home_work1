# %% [markdown]
# <a href="https://colab.research.google.com/github/lymura/Home_work1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3_3%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#уравнение гиперболы
from sympy import plot_implicit, Eq
from sympy.abc import x, y

a = -5
b = 1
plot_implicit(Eq((y - a * x) * (y - b * x), -1), (x, -10, 10), (y, -10, 10))

# %%
#уравнение параболы
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
p = 2
x = np.linspace(-5, 5, 1000)
y1 = np.sqrt(3 - 2*p*x)
y2 = -np.sqrt(3 - 2*p*x)
plt.ylim(-1,5, 1,5)
plt.xlim(-4, 4)
plt.plot(x, y1)
plt.plot(x, y2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sqrt
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in sqrt
#   if __name__ == '__main__':

# %%
#Уравнение эллипса
# %matplotlib inline
import numpy as np
import math
import matplotlib.pyplot as plt
a = 4
b = 2
x = np.linspace(-5, 5, 1000)
y1 = np.sqrt((1 - (x**2)/a**2)/3**b)
y2 = -np.sqrt((1 - (x**2)/a**2)/3**b)
plt.ylim(-1,5, 1,5)
plt.xlim(-4, 4)
plt.plot(x, y1)
plt.plot(x, y2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in sqrt
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.

# %%
#уравнение окружности
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 1000)
y1 = np.sqrt((r**2 - x**2)/3)
y2 = -np.sqrt((r**2 - x**2)/3)
plt.ylim(-1.5, 1.5)
plt.xlim(-4, 4)
plt.plot(x, y1)
plt.plot(x, y2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sqrt
